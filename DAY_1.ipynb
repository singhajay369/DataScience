# %% [markdown]
# <a href="https://colab.research.google.com/github/singhajay369/DataScience/blob/main/DAY_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY 1

# %% [markdown]
# learn about python exectuion pipeline .py-> tokenization -> parsing ->ast->compiler-> bytecode -> pvm(interpreter)-> out put

# %%
# Variable -

# %% [markdown]
# # **Variable**
#
# a = 10
# is ka mtlb h
# memory me ek obj. -> 10 bngaya h
# jise point krta h "a" mtlb ek uski memroy address ka naam h
#
#     |-----------|
#     |    10     | <--------- a
#     |-----------|

# %%
a = 10

a
# Out:
# 10

# %%
a + 21
# Out:
# 31

# %%
a = 'ajay'

# %%
a
# Out:
# 'ajay'

# %%
a + "90"
# Out:
# 'ajay90'

# %%
type(a)
# Out:
# str

# %% [markdown]
# input() - input funtion use to take input from user

# %%
name = input("Enter your name ")
# Out:
# Enter your name Ajay Singh

# %%
print(name)
# Out:
# Ajay Singh

# %% [markdown]
# *"**LEGB**" (LOCAL-ENCLOSED-GLOBAL-BUILD_IN)

# %%
x = 21

def f():
  print(x)

  def y():
    x = 10

# %%
f()
# Out:
# 21

# %%
x
# Out:
# 21

# %%
x = 21
def f():
  print(x)

  def y():
    print(x)

  return y()

# %%
f()
# Out:
# 21
# 21

# %% [markdown]
# Funtion enclosing - koi bhi function enclose tab bnta h jab vo koi bhi value print kr rha ho to use uske phaly wale funtion se read kare na ki assign , different value assign kr skta h but not the same agar same karega to vo ek Local Varibale bana dega jise vo "LEGB" according run karega , for eg.

# %%
x = 21 #global varibale h

# %% [markdown]
# # 📝 Topic: Mutable vs Immutable (Memory & Scope Logic)
#
# ### **1. The Core Mental Model (Analogy)**
# * **Immutable (Stone Statue 🗿):** Change nahi kar sakte. Change karne ke liye **purana feko, naya banao**.
#
#   Immutable modify karne ke liye global/nonlocal kyu chahiye?
#
#     Because:
#     ❗ Immutable cannot be modified — only REASSIGNED.
#
#       Matlab:
#
#           x = 5
#         def f():
#         x = x + 1   # ❌ new value ban rahi hai → rebinding → Python makes x local
#
#
#   Assignment → makes x LOCAL, causing:
#
#   Shadowing
#
#   Or error (UnboundLocalError)
#
#   To modify global/enclosing variables, you MUST tell Python:
#
#   global x
#
#   or nonlocal x
#
#   Otherwise Python bolta hai:
#
#   “You assigned to x → so x is LOCAL → global x untouched.”
#
#     * *Ex:* `int`, `float`, `str`, `tuple`.
#
#
#
#
# * **Mutable (School Bag 🎒):** Bag wahi rehta hai, bas andar ka **samaan badalta hai**.
#
#     * mutable ko modify karne ke liye global/nonlocal nahi chahiye
#
#       You are NOT changing the variable,
#
#       you are only changing the object’s content.
#
#     * *Ex:* `list`, `dict`, `set`.
#
#           lst = [1, 2, 3]
#           def f():
#         lst.append(4) # allowed, no global needed
#
#         lst.append() → list object modify hota hai
#
#         But lst variable ka reference change nahi hota.
#
#         Isliye Python ko koi issue nahi.
#
# ---
#
# ### **2. Memory Level Behavior (The "Why")**
# * **Reassignment (`x = x + 1`):**
#     * Python calculates `x + 1`.
#     * Creates a **NEW object** at a **NEW memory address**.
#     * Moves the label `x` to the new address. (Rebinding).
# * **Mutation (`lst.append(4)`):**
#     * Python goes to the **SAME memory address**.
#     * Adds data inside the existing object directly. (In-place modification).
#
# ---
#
# ### **3. The LEGB/Scope Conflict (Why Global?)**
# * **The Trap:** Python mein `=` (Assignment Operator) ka matlab hai **"Make a NEW Local Variable"**.
#
# | Scenario | Code | What Python Thinks | Need Global? |
# | :--- | :--- | :--- | :--- |
# | **A. Reassignment (Immutable)** | `x = x + 1` | `=` dekha → "Oh, new local variable `x` bana rahe ho?" → Error if not global. | **YES** (`global x`) |
# | **B. Mutation (Mutable)** | `lst.append(4)` | No `=` sign → "Oh, modify karna hai? Global `lst` use kar leta hu." | **NO** |
#
# ---
#
# ### **4. Summary Table (Cheat Sheet)**
#
# | Type | Examples | Action | `=` Used? | Memory Address | Need `global`? |
# | :--- | :--- | :--- | :--- | :--- | :--- |
# | **Immutable** | `int`, `str`, `tuple` | `x = 5` | ✅ Yes | **Changes** (New Object) | **YES** |
# | **Mutable** | `list`, `dict` | `.append()` | ❌ No | **Same** (In-place) | **NO** |
#
# ---
#
# ### **5. The Golden Rule (For Production Code)**
# > 🔹 **Mutation (Internal Change)** $\rightarrow$ **NO Global needed.**
# >
# > 🔹 **Reassignment (Variable Change)** $\rightarrow$ **YES Global needed.**
#
# ---
#
# ### **6. Proof of Concept (Code)**
# ```python
# # Run this to verify Memory IDs
#
# # Mutable (List) - Address SAME
# L = [1]
# print(f"List Original ID: {id(L)}")
# L.append(2)
# print(f"List After Append ID: {id(L)}")  # ID same rahegi ✔
#
# # Immutable (Int) - Address CHANGES
# x = 10
# print(f"Int Original ID: {id(x)}")
# x = x + 1
# print(f"Int After Reassign ID: {id(x)}")  # ID change hogi ⚠
#
#
#
#
#
# ⭐ THE GOLDEN RULE (Remember Forever)
# 🔹 Mutation does NOT require global/nonlocal
#
# (lists, dicts, sets)
#
# 🔹 Reassignment DOES require global/nonlocal
#
#
# (int, float, str, tuple)

# %% [markdown]
# # NAMESPACE vs SCOPE
#
#
#  NAMESPACE → "Ghar"
#  (Variable jahan rehta hai)
#
#  SCOPE → "Awaaz ki range"
#  (Variable jahan tak visible/accessible hota hai)
#
#
#  -------------------------------
#  Namespace Examples
#  -------------------------------
#
# x = 10     # Global namespace
#
# def f():
#
# y = 20   # Local namespace
#
# print(x) # x is NOT local → Python checks outer namespaces
#
#
#  -------------------------------
# - x global namespace me store hota hai
#
# - y local namespace me store hota hai
#
# - f() ke andar x visible hai → kyunki global scope visible hota hai
#
# - f() ke bahar y visible nahi hai → kyunki local scope limited hota hai
#
#
#  -------------------------------
#  FINAL DIFFERENCE (1-liners)
#  -------------------------------
#  Namespace = jahan variable STORE hota hai.
#  Scope     = jahan variable ACCESSIBLE hota hai.
#
#  Namespace → storage container
#  Scope     → visibility rules (LEGB)

# %% [markdown]
# -----------------------------------------
#
# 1. locals() → current function ke local variables dikhta hai
#
# 2. globals() → module ke global variables
#
# 3. inspect.getclosurevars() → closure ke variables
#
# 4. func.__closure__ → captured variables
# -------------------------------------------------

# %%
print("DS Track started")
# Out:
# DS Track started

# %%
def hello():
    print("hi")

dis.dis(hello)
# Out:
#   1           0 RESUME                   0
#
#   2           2 LOAD_GLOBAL              1 (NULL + print)
#              12 LOAD_CONST               1 ('hi')
#              14 CALL                     1
#              22 POP_TOP
#              24 RETURN_CONST             0 (None)

# %%
a = 10; b = 10; c = 257; d = 257
print(a is b)
print(c is d)
# Out:
# True
# False

# %%
x = [1,2,3];
y = x;
y.append(99);
print(x);
print(y)
# Out:
# [1, 2, 3, 99]
# [1, 2, 3, 99]

# %%
def add(a,b): return a + b
import dis
dis.dis(add)
# Out:
#   1           0 RESUME                   0
#               2 LOAD_FAST                0 (a)
#               4 LOAD_FAST                1 (b)
#               6 BINARY_OP                0 (+)
#              10 RETURN_VALUE

# %%
x = [1,2,3]
y = x
x = x + [4]
print(y); print(x)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]

# %%
import dis
import sys

def tracker():
    a = 5
    b = "Hello"
    c = [1,2,3]

    print("IDs:", id(a), id(b), id(c))
    print("Sizes:", sys.getsizeof(a), sys.getsizeof(b), sys.getsizeof(c))

    def inner():
        x = 99
        print("Inner locals:", locals())

    inner()
    print("Bytecode of inner:")
    dis.dis(inner)

tracker()
# Out:
# IDs: 11654504 137540446220912 137540465900928
# Sizes: 28 46 88
# Inner locals: {'x': 99}
# Bytecode of inner:
#  12           0 RESUME                   0
#
#  13           2 LOAD_CONST               1 (99)
#               4 STORE_FAST               0 (x)
#
#  14           6 LOAD_GLOBAL              1 (NULL + print)
#              16 LOAD_CONST               2 ('Inner locals:')
#              18 LOAD_GLOBAL              3 (NULL + locals)
#              28 CALL                     0
#              36 CALL                     2
#              44 POP_TOP
#              46 RETURN_CONST             0 (None)
