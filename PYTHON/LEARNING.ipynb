# %%
a = 21
print(a)
print(id(a))  # id function returns the memory address of the variable
a = 22
print(a)
print(id(a))  # memory address changes when value is updated
print(type(a))  # type function returns the data type of the variable
# Out:
# 21
# 140717821974056
# 22
# 140717821974088
# <class 'int'>

# %%
print("Ajay Singh")
# Out:
# Ajay Singh

# %%
print(231)
# Out:
# 231

# %%
print(True)
# Out:
# True

# %%
print(" Ajay", "Harry", "Rahul", "Abhishek", sep=", \n ")  # sep parameter in print function to change separator
# Out:
#  Ajay,
#  Harry,
#  Rahul,
#  Abhishek

# %%
print("Ajay", "Harry", "Rahul", "Abhishek", sep="-")
# Out:
# Ajay-Harry-Rahul-Abhishek

# %%
print("Ajay", "Harry", "Rahul", "Abhishek", sep="-", end = " ") 
# end is used to specify what to print at the end of the output
# sep is used to separate multiple values with a specified character
# Out:
# Ajay-Harry-Rahul-Abhishek
