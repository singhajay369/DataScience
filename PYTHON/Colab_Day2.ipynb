# %% [markdown]
# <a href="https://colab.research.google.com/github/singhajay369/DataScience/blob/main/PYTHON/Colab_Day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- ⚡ DAILY STARTUP CELL (RUN ONCE) ---
import os
from google.colab import drive

# 1. Google Drive connect karlo (Authentication ke liye)
drive.mount('/content/drive')

# 2. Repo ko wapas bulao (Clone or Pull)
repo_path = "/content/DataScience"
repo_url = "https://github.com/singhajay369/DataScience.git"

if not os.path.exists(repo_path):
    print("🚀 Naya Session: Repo Clone kar raha hu...")
    # !git clone $repo_url
else:
    print("🔄 Session Active: Updates check kar raha hu...")
    # !cd $repo_path && git pull origin main

# 3. User Identity Set karlo (Taaki baar baar na batana pade)
# !cd $repo_path && git config --global user.email "singhajay369@gmail.com"
# !cd $repo_path && git config --global user.name "Ajay Singh"

print("\n✅ READY! Ab Day 2 ka kaam shuru kar bindass.")
# Out:
# Mounted at /content/drive
# 🚀 Naya Session: Repo Clone kar raha hu...
# Cloning into 'DataScience'...
# remote: Enumerating objects: 208, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 208 (delta 4), reused 5 (delta 2), pack-reused 197 (from 3)
# Receiving objects: 100% (208/208), 159.37 MiB | 28.90 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# Updating files: 100% (134/134), done.
#
# ✅ READY! Ab Day 2 ka kaam shuru kar bindass.

# %% [markdown]
# # if else

# %%
# --- STEP 4: AUTO-SYNC TO GITHUB ---
import shutil
import os

# 1. File ko sahi jagah move karna (Root -> PYTHON folder)
source = "/content/Colab_DAY2.ipynb"
destination = "/content/DataScience/PYTHON/Colab_DAY2.ipynb"

# Pehle current file ko forcefully save karo (Ctrl+S yaad dila raha hu)
print("⚠️ PEHLE 'Ctrl + S' DABAO TAAKI LATEST KAAM SAVE HO JAYE!")
input("Agar Ctrl+S daba diya hai to Enter maaro...")

if os.path.exists(source):
    shutil.copy(source, destination)
    print(f"✅ File moved to: {destination}")
else:
    print("❌ File nahi mili! Kya tumne filename 'Colab_DAY2.ipynb' hi rakha hai?")

# 2. Git Push (Identity set + Push)
print("\n🚀 Pushing to GitHub...")
# !cd /content/DataScience && git config --global user.email "singhajay369@gmail.com"
# !cd /content/DataScience && git config --global user.name "Ajay Singh"
# !cd /content/DataScience && git add .
# !cd /content/DataScience && git commit -m "Day 2: Python Learning Completed"

# Note: Agar ye push password maange, to apna Token (ghp_...) paste karna
# !cd /content/DataScience && git push origin main
# Out:
# ⚠️ PEHLE 'Ctrl + S' DABAO TAAKI LATEST KAAM SAVE HO JAYE!
# Agar Ctrl+S daba diya hai to Enter maaro...
# ❌ File nahi mili! Kya tumne filename 'Colab_DAY2.ipynb' hi rakha hai?
#
# 🚀 Pushing to GitHub...
# /bin/bash: line 1: cd: /content/DataScience: No such file or directory
# /bin/bash: line 1: cd: /content/DataScience: No such file or directory
# /bin/bash: line 1: cd: /content/DataScience: No such file or directory
# /bin/bash: line 1: cd: /content/DataScience: No such file or directory
# /bin/bash: line 1: cd: /content/DataScience: No such file or directory
