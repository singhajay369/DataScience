# %% [markdown]
# <a href="https://colab.research.google.com/github/singhajay369/DataScience/blob/main/ColabDAY_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##LIST

# %%
l = [] #empty list

# %%
l
# Out:
# []

# %%
# Homogenious list( list that contain data of same data type)
L = [1,2,3,4,5]

# %%
L
# Out:
# [1, 2, 3, 4, 5]

# %%
# Hetrogenious list (contain data of multiple data types)
L1 =["Ajay", 21, "Data Scientist" ]
L1
# Out:
# ['Ajay', 21, 'Data Scientist']

# %%
L1[0] # fist index is always 0
# Out:
# 'Ajay'
