# %% [markdown]
# <a href="https://colab.research.google.com/github/singhajay369/DataScience/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY 1

# %%
# Variable -

# %%
a = 10

a
# Out:
# 10

# %%
a + 21
# Out:
# 31

# %%
a = 'ajay'

# %%
a
# Out:
# 'ajay'

# %%
a + "90"
# Out:
# 'ajay90'

# %%
type(a)
# Out:
# str
